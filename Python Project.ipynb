# %%
# importing pandas
import pandas as pd

# read file
df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
print(df)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# quesion 2
df.groupby('Area') ['Y2017'].sum('Y2017')
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
# question 4
df.groupby('Area') ['Y2017'].sum('Y2017')
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
# question 6
df.describe().round(2)
# Out:
#        Area Code  Item Code  Element Code      Y2014      Y2015      Y2016  \
# count   60943.00   60943.00      60943.00   59354.00   59395.00   59408.00
# mean      134.27    2687.18       3814.86     134.20     135.24     136.56
# std        72.61     146.06       2212.01    1567.66    1603.40    1640.01
# min         4.00    2501.00        511.00   -1796.00   -3161.00   -3225.00
# 25%        74.00    2562.00        684.00       0.00       0.00       0.00
# 50%       136.00    2630.00       5142.00       0.09       0.08       0.08
# 75%       195.00    2775.00       5511.00       8.34       8.46       8.43
# max       276.00    2961.00       5911.00  176405.00  181137.00  185960.00
#
#            Y2017      Y2018
# count   59437.00   59507.00
# mean      140.92     143.76
# std      1671.86    1710.78
# min     -1582.00   -3396.00
# 25%         0.00       0.00
# 50%         0.10       0.07
# 75%         9.00       9.00
# max    190873.00  195875.00

# %%
# question 7
df.groupby('Element')[['Y2014','Y2015','Y2016','Y2017','Y2018']].count()
# Out:
#                                         Y2014  Y2015  Y2016  Y2017  Y2018
# Element
# Domestic supply quantity                 5244   5245   5250   5258   5256
# Export Quantity                          3660   3704   3653   3660   3646
# Fat supply quantity (g/capita/day)       4965   4974   4980   4982   4987
# Feed                                     1216   1177   1215   1213   1225
# Food                                     4896   4901   4910   4912   4913
# Food supply (kcal/capita/day)            4947   4955   4963   4965   4969
# Food supply quantity (kg/capita/yr)      4860   4865   4874   4876   4877
# Import Quantity                          4919   4911   4908   4929   4945
# Losses                                   2009   2009   2009   2009   2008
# Other uses (non-food)                    1662   1667   1634   1619   1655
# Processing                               1987   1995   1996   1998   2003
# Production                               3830   3828   3838   3829   3846
# ...

# %%
# question 12
df.groupby('Item') [["Y2015", "Y2018"]].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
# question 16
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# question 17
df.groupby('Area')['Area'].count().nunique()
# Out:
# 46

# %%
# question 18
df.groupby('Element Code')[['Y2014','Y2015','Y2016','Y2017','Y2018']].count()
# Out:
#               Y2014  Y2015  Y2016  Y2017  Y2018
# Element Code
# 511              45     45     45     45     45
# 645            4860   4865   4874   4876   4877
# 664            4947   4955   4963   4965   4969
# 674            4963   4971   4978   4980   4986
# 684            4965   4974   4980   4982   4987
# 5072           4230   4229   4231   4231   4217
# 5123           2009   2009   2009   2009   2008
# 5131           1987   1995   1996   1998   2003
# 5142           4896   4901   4910   4912   4913
# 5154           1662   1667   1634   1619   1655
# 5170           4604   4605   4610   4618   4616
# 5171            555    555    555    555    555
# 5301           5244   5245   5250   5258   5256
# 5511           3830   3828   3838   3829   3846
# 5521           1216   1177   1215   1213   1225
# 5527            762    759    759    758    758
# 5611           4919   4911   4908   4929   4945
# 5911           3660   3704   3653   3660   3646

# %%
# question 20
df.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...
